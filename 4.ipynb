# %%
from sqlalchemy import create_engine


engine = create_engine("sqlite:///example.db", echo=False)

# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import Mapped, mapped_column


class Base(DeclarativeBase):
    pass


class ToDo(Base):
    __tablename__ = "todos"

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str] = mapped_column(nullable=True)
    description: Mapped[str] = mapped_column(nullable=True)

# %%
# Create the table in the database
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import Session


with Session(engine) as session:
    todo = ToDo(title="Buy groceries", description="Buy groceries")
    session.add(todo)
    session.commit()

# %%
from sqlalchemy import select


with Session(engine) as session:
    statement = select(ToDo)
    result = session.execute(statement=statement)
    todos = result.scalars().all()

for todo in todos:
    for key, value in todo.__dict__.items():
        print(key, value)
# Out:
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC828A380>
# description Buy groceries
# id 1
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC823B9A0>
# description Buy groceries
# id 2
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3E860>
# description Get a haircut
# id 3
# title Get a haircut
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3FB80>
# description Buy a new laptop
# id 5
# title Buy a new laptop
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3CE20>
# description Buy a new car
# id 6
# title Buy a new car
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3C160>
# description Buy a new house
# id 7
# title Buy a new house
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3E380>
# description Buy a new boat
# id 8
# title Buy a new boat
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3D540>
# description Buy a new plane
# id 9
# title Buy a new plane
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3EE60>
# description Buy a new island
# id 10
# title Buy a new island
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3E7A0>
# description Buy a new moon
# id 11
# title Buy a new moon
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC8D3D300>
# description Buy a new sun
# id 12
# title Buy a new sun
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC6670B80>
# description Buy groceries
# id 13
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB206440>
# description Buy groceries
# id 14
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB2046A0>
# description Get a haircut
# id 15
# title Get a haircut
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB204880>
# description Buy a new laptop
# id 17
# title Buy a new laptop
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB206BC0>
# description Buy a new car
# id 18
# title Buy a new car
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB207AC0>
# description Buy a new house
# id 19
# title Buy a new house
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB2042E0>
# description Buy a new boat
# id 20
# title Buy a new boat
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB204B80>
# description Buy a new plane
# id 21
# title Buy a new plane
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB205900>
# description Buy a new island
# id 22
# title Buy a new island
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203D60>
# description Buy a new moon
# id 23
# title Buy a new moon
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB201C60>
# description Buy a new sun
# id 24
# title Buy a new sun
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203400>
# description Walk the dog in the park
# id 25
# title Walk the dog
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203280>
# description Buy groceries
# id 26
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB2018A0>
# description Buy groceries
# id 27
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203100>
# description Get a haircut
# id 28
# title Get a haircut
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B8BE0>
# description Buy a new laptop
# id 30
# title Buy a new laptop
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B8C40>
# description Buy a new car
# id 31
# title Buy a new car
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B8820>
# description Buy a new house
# id 32
# title Buy a new house
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BBEE0>
# description Buy a new boat
# id 33
# title Buy a new boat
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BACE0>
# description Buy a new plane
# id 34
# title Buy a new plane
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BB040>
# description Buy a new island
# id 35
# title Buy a new island
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BAFE0>
# description Buy a new moon
# id 36
# title Buy a new moon
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BAF80>
# description Buy a new sun
# id 37
# title Buy a new sun
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BAF20>
# description Walk the dog in the park
# id 38
# title Walk the dog
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BAE60>
# description Buy groceries
# id 39
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BAEC0>
# description Buy groceries
# id 40
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA6E0>
# description Get a haircut
# id 41
# title Get a haircut
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA620>
# description Buy a new laptop
# id 43
# title Buy a new laptop
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA680>
# description Buy a new car
# id 44
# title Buy a new car
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA5C0>
# description Buy a new house
# id 45
# title Buy a new house
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA020>
# description Buy a new boat
# id 46
# title Buy a new boat
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA560>
# description Buy a new plane
# id 47
# title Buy a new plane
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA500>
# description Buy a new island
# id 48
# title Buy a new island
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA4A0>
# description Buy a new moon
# id 49
# title Buy a new moon
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA440>
# description Buy a new sun
# id 50
# title Buy a new sun
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA3E0>
# description Walk the dog in the park
# id 51
# title Walk the dog
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA380>
# description Buy groceries
# id 52
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA320>
# description Buy groceries
# id 53
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA2C0>
# description Get a haircut
# id 54
# title Get a haircut
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA260>
# description Buy a new laptop
# id 56
# title Buy a new laptop
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA200>
# description Buy a new car
# id 57
# title Buy a new car
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA1A0>
# description Buy a new house
# id 58
# title Buy a new house
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA140>
# description Buy a new boat
# id 59
# title Buy a new boat
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA0E0>
# description Buy a new plane
# id 60
# title Buy a new plane
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6BA080>
# description Buy a new island
# id 61
# title Buy a new island
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9E40>
# description Buy a new moon
# id 62
# title Buy a new moon
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9FC0>
# description Buy a new sun
# id 63
# title Buy a new sun
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9F60>
# description Walk the dog in the park
# id 64
# title Walk the dog
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9F00>
# description Buy groceries
# id 65
# title Buy groceries
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9EA0>
# description Buy groceries
# id 66
# title Buy groceries

# %%
todos = [
    ToDo(title="Buy groceries", description="Buy groceries"),
    ToDo(title="Get a haircut", description="Get a haircut"),
    ToDo(title="Buy a new phone", description="Buy a new phone"),
    ToDo(title="Buy a new laptop", description="Buy a new laptop"),
    ToDo(title="Buy a new car", description="Buy a new car"),
    ToDo(title="Buy a new house", description="Buy a new house"),
    ToDo(title="Buy a new boat", description="Buy a new boat"),
    ToDo(title="Buy a new plane", description="Buy a new plane"),
    ToDo(title="Buy a new island", description="Buy a new island"),
    ToDo(title="Buy a new moon", description="Buy a new moon"),
    ToDo(title="Buy a new sun", description="Buy a new sun"),
]

with Session(engine) as session:
    session.add_all(todos)
    session.commit()

# %%
with Session(engine) as session:
    statement = select(ToDo).filter_by(title="Buy a new phone")
    todo = session.execute(statement=statement).scalar_one()
    todo.title = "Buy a new charger"
    todo.description = "Buy a new charger"
    session.commit()

# %%
with Session(engine) as session:
    statement = select(ToDo).filter_by(title="Buy a new charger")
    todo = session.execute(statement=statement).scalar_one()
    session.delete(todo)
    session.commit()

# %%
# Core foundations of SQLAlchemy ORM
from sqlalchemy import create_engine


engine = create_engine("sqlite:///example.db", echo=False)

from sqlalchemy import Table, Column, Integer, String, MetaData

metadata = MetaData()

todos_table = Table(
    "todos", 
    metadata, 
    Column("id", Integer, primary_key=True),
    Column("title", String, nullable=True),
    Column("description", String, nullable=True)
)

metadata.create_all(engine)

# %%
# Inserting Data
from sqlalchemy import insert

statement = insert(todos_table).values(title="Walk the dog", description="Walk the dog in the park")

with engine.connect() as connection:
    connection.execute(statement)
    connection.commit()


# Selecting Data
from sqlalchemy import select


statement = select(todos_table)

with engine.connect() as connection:
    result = connection.execute(statement)
    todos = result.fetchall()
    for todo in todos:
        print(todo)
# Out:
# (1, 'Buy groceries', 'Buy groceries')
# (2, 'Buy groceries', 'Buy groceries')
# (3, 'Get a haircut', 'Get a haircut')
# (5, 'Buy a new laptop', 'Buy a new laptop')
# (6, 'Buy a new car', 'Buy a new car')
# (7, 'Buy a new house', 'Buy a new house')
# (8, 'Buy a new boat', 'Buy a new boat')
# (9, 'Buy a new plane', 'Buy a new plane')
# (10, 'Buy a new island', 'Buy a new island')
# (11, 'Buy a new moon', 'Buy a new moon')
# (12, 'Buy a new sun', 'Buy a new sun')
# (13, 'Buy groceries', 'Buy groceries')
# (14, 'Buy groceries', 'Buy groceries')
# (15, 'Get a haircut', 'Get a haircut')
# (17, 'Buy a new laptop', 'Buy a new laptop')
# (18, 'Buy a new car', 'Buy a new car')
# (19, 'Buy a new house', 'Buy a new house')
# (20, 'Buy a new boat', 'Buy a new boat')
# (21, 'Buy a new plane', 'Buy a new plane')
# (22, 'Buy a new island', 'Buy a new island')
# (23, 'Buy a new moon', 'Buy a new moon')
# (24, 'Buy a new sun', 'Buy a new sun')
# (25, 'Walk the dog', 'Walk the dog in the park')
# (26, 'Buy groceries', 'Buy groceries')
# (27, 'Buy groceries', 'Buy groceries')
# (28, 'Get a haircut', 'Get a haircut')
# (30, 'Buy a new laptop', 'Buy a new laptop')
# (31, 'Buy a new car', 'Buy a new car')
# (32, 'Buy a new house', 'Buy a new house')
# (33, 'Buy a new boat', 'Buy a new boat')
# (34, 'Buy a new plane', 'Buy a new plane')
# (35, 'Buy a new island', 'Buy a new island')
# (36, 'Buy a new moon', 'Buy a new moon')
# (37, 'Buy a new sun', 'Buy a new sun')
# (38, 'Walk the dog', 'Walk the dog in the park')
# (39, 'Buy groceries', 'Buy groceries')
# (40, 'Buy groceries', 'Buy groceries')
# (41, 'Get a haircut', 'Get a haircut')
# (43, 'Buy a new laptop', 'Buy a new laptop')
# (44, 'Buy a new car', 'Buy a new car')
# (45, 'Buy a new house', 'Buy a new house')
# (46, 'Buy a new boat', 'Buy a new boat')
# (47, 'Buy a new plane', 'Buy a new plane')
# (48, 'Buy a new island', 'Buy a new island')
# (49, 'Buy a new moon', 'Buy a new moon')
# (50, 'Buy a new sun', 'Buy a new sun')
# (51, 'Walk the dog', 'Walk the dog in the park')
# (52, 'Buy groceries', 'Buy groceries')
# (53, 'Buy groceries', 'Buy groceries')
# (54, 'Get a haircut', 'Get a haircut')
# (56, 'Buy a new laptop', 'Buy a new laptop')
# (57, 'Buy a new car', 'Buy a new car')
# (58, 'Buy a new house', 'Buy a new house')
# (59, 'Buy a new boat', 'Buy a new boat')
# (60, 'Buy a new plane', 'Buy a new plane')
# (61, 'Buy a new island', 'Buy a new island')
# (62, 'Buy a new moon', 'Buy a new moon')
# (63, 'Buy a new sun', 'Buy a new sun')
# (64, 'Walk the dog', 'Walk the dog in the park')
# (65, 'Buy groceries', 'Buy groceries')
# (66, 'Buy groceries', 'Buy groceries')
# (67, 'Buy groceries', 'Buy groceries')
# (68, 'Get a haircut', 'Get a haircut')
# (70, 'Buy a new laptop', 'Buy a new laptop')
# (71, 'Buy a new car', 'Buy a new car')
# (72, 'Buy a new house', 'Buy a new house')
# (73, 'Buy a new boat', 'Buy a new boat')
# (74, 'Buy a new plane', 'Buy a new plane')
# (75, 'Buy a new island', 'Buy a new island')
# (76, 'Buy a new moon', 'Buy a new moon')
# (77, 'Buy a new sun', 'Buy a new sun')
# (78, 'Walk the dog', 'Walk the dog in the park')

# %% [markdown]
# ORM Basics

# %%
import datetime
from sqlalchemy.orm import declarative_base

Base = declarative_base()


from sqlalchemy import Column, Integer, String, DateTime, Boolean

class User(Base):
    __tablename__ = "users"

    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=True)
    is_active = Column(Boolean, default=True)
    created_at = Column(DateTime, default=datetime.datetime.now)


Base.metadata.create_all(engine)

# %%
# Sessions (VERY IMPORTANT)
from sqlalchemy.orm import sessionmaker

SessionLocal = sessionmaker(bind=engine)
session = SessionLocal()

# %%
users = [
    User(name="Alice"),
    User(name="Bob"),
    User(name="Charlie"),
    User(name="Dave"),
    User(name="Eve"),
]

for user in users:
    session.add(user)
    session.commit()

session.add_all(users)
session.commit()

users = session.query(User).all()

for user in users:
    print(user.id, user.name, user.is_active, user.created_at)
# Out:
# 1 Alice True 2026-01-14 22:19:29.236599
# 2 Bob True 2026-01-14 22:19:29.236599
# 3 Charlie True 2026-01-14 22:19:29.236599
# 4 Dave True 2026-01-14 22:19:29.236599
# 5 Eve True 2026-01-14 22:19:29.236599
# 6 Alice True 2026-01-15 16:27:08.117127
# 7 Bob True 2026-01-15 16:27:08.294889
# 8 Charlie True 2026-01-15 16:27:08.408266
# 9 Dave True 2026-01-15 16:27:08.538241
# 10 Eve True 2026-01-15 16:27:08.657943
# 11 Alice True 2026-01-16 20:44:47.109342
# 12 Bob True 2026-01-16 20:44:47.251003
# 13 Charlie True 2026-01-16 20:44:47.428983
# 14 Dave True 2026-01-16 20:44:47.551127
# 15 Eve True 2026-01-16 20:44:47.725328
# 16 Alice True 2026-01-17 23:07:04.702524
# 17 Bob True 2026-01-17 23:07:04.820589
# 18 Charlie True 2026-01-17 23:07:04.988969
# 19 Dave True 2026-01-17 23:07:05.112080
# 20 Eve True 2026-01-17 23:07:05.251115
# 21 Alice True 2026-01-19 16:39:33.754077
# 22 Bob True 2026-01-19 16:39:34.029185
# 23 Charlie True 2026-01-19 16:39:34.147111
# 24 Dave True 2026-01-19 16:39:34.255373
# 25 Eve True 2026-01-19 16:39:34.355807

# %%
users = session.query(User).filter(User.name == "Alice").all()
for user in users:
    print(user.id, user.name, user.is_active, user.created_at)
# Out:
# 1 Alice True 2026-01-14 22:19:29.236599
# 6 Alice True 2026-01-15 16:27:08.117127
# 11 Alice True 2026-01-16 20:44:47.109342
# 16 Alice True 2026-01-17 23:07:04.702524
# 21 Alice True 2026-01-19 16:39:33.754077

# %%
from typing import List, Optional
from sqlalchemy.orm import Mapped, mapped_column, relationship
from sqlalchemy import ForeignKey


class Category(Base):
    __tablename__ = "categories"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] = mapped_column(nullable=True)
    description: Mapped[Optional[str]] = mapped_column(nullable=True)
    products: Mapped[List["Product"]] = relationship(back_populates="category")

    def __repr__(self) -> str:
        return f"Category(id={self.id!r}, name={self.name!r}, description={self.description!r})"


class Product(Base):
    __tablename__ = "products"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[str] = mapped_column(nullable=True)
    description: Mapped[str] = mapped_column(nullable=True)
    category_id: Mapped[int] = mapped_column(ForeignKey("categories.id"))

    category: Mapped[Category] = relationship(back_populates="products")

    def _repr__(self) -> str:
        return f"Product(id={self.id!r}, name={self.name!r}, description={self.description!r}, category_id={self.category_id!r})"

# %%
Base.metadata.create_all(engine)

# %%
categories = [
    Category(name="Electronics", description="Electronic items"),
    Category(name="Clothing", description="Clothing items"),
    Category(name="Books", description="Books and literature"),
]

for category in categories:
    session.add(category)
    session.commit()

products = [
    Product(name="Laptop", description="A personal computer", category_id=1),
    Product(name="Smartphone", description="A mobile phone", category_id=1),
    Product(name="T-Shirt", description="A cotton t-shirt", category_id=2),
    Product(name="Jeans", description="Denim jeans", category_id=2),
    Product(name="Novel", description="A fiction book", category_id=3),
    Product(name="Biography", description="A non-fiction book", category_id=3),
]

session.add_all(products)
session.commit()

# %%
categories = session.query(Category).all()
for category in categories:
    print(category)

products = session.query(Product).all()
for product in products:
    for key, value in product.__dict__.items():
        print(key, value)
# Out:
# Category(id=1, name='Electronics', description='Electronic items')
# Category(id=2, name='Clothing', description='Clothing items')
# Category(id=3, name='Books', description='Books and literature')
# Category(id=4, name='Electronics', description='Electronic items')
# Category(id=5, name='Clothing', description='Clothing items')
# Category(id=6, name='Books', description='Books and literature')
# Category(id=7, name='Electronics', description='Electronic items')
# Category(id=8, name='Clothing', description='Clothing items')
# Category(id=9, name='Books', description='Books and literature')
# Category(id=10, name='Electronics', description='Electronic items')
# Category(id=11, name='Clothing', description='Clothing items')
# Category(id=12, name='Books', description='Books and literature')
# Category(id=13, name='Electronics', description='Electronic items')
# Category(id=14, name='Clothing', description='Clothing items')
# Category(id=15, name='Books', description='Books and literature')
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6260>
# id 2
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F62C0>
# id 3
# name T-Shirt
# category_id 2
# description A cotton t-shirt
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6320>
# id 4
# name Jeans
# category_id 2
# description Denim jeans
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6380>
# id 5
# name Novel
# category_id 3
# description A fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F63E0>
# id 6
# name Biography
# category_id 3
# description A non-fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6440>
# id 7
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F64A0>
# id 8
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6500>
# id 9
# name T-Shirt
# category_id 2
# description A cotton t-shirt
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6560>
# id 10
# name Jeans
# category_id 2
# description Denim jeans
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F65C0>
# id 11
# name Novel
# category_id 3
# description A fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6620>
# id 13
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6680>
# id 14
# name T-Shirt
# category_id 2
# description A cotton t-shirt
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F66E0>
# id 15
# name Jeans
# category_id 2
# description Denim jeans
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6740>
# id 16
# name Novel
# category_id 3
# description A fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F67A0>
# id 17
# name Biography
# category_id 3
# description A non-fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6800>
# id 18
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6860>
# id 19
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F68C0>
# id 20
# name T-Shirt
# category_id 2
# description A cotton t-shirt
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6920>
# id 21
# name Jeans
# category_id 2
# description Denim jeans
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6980>
# id 22
# name Novel
# category_id 3
# description A fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F69E0>
# id 23
# name Biography
# category_id 3
# description A non-fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC828A920>
# id 24
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB075420>
# id 25
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B8EE0>
# id 26
# name T-Shirt
# category_id 2
# description A cotton t-shirt
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B9A20>
# id 27
# name Jeans
# category_id 2
# description Denim jeans
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6B8B80>
# id 28
# name Novel
# category_id 3
# description A fiction book
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB670CA0>
# id 29
# name Biography
# category_id 3
# description A non-fiction book

# %%
from os import name


def print_products_details(products):
    for product in products:
        for key, value in product.__dict__.items():
            print(key, value)

def print_product_details(product):
    if product:
        for key, value in product.__dict__.items():
            print(key, value)

products = session.query(Product).filter(Product.name == "Laptop").all()
print_products_details(products)

products = session.query(Product).filter(Product.name.icontains("Laptop")).all()
print_products_details(products)

products = session.query(Product).filter(Product.category.has(name="Electronics")).all()
print_products_details(products)

products = session.query(Product).filter(Product.name.ilike("%phone%"), Product.category.has(name="Electronics")).all()
print_products_details(products)

product = session.query(Product).filter(Product.name.ilike("%top%"), Product.category.has(name="Electronics")).first()
print_product_details(product)

product = session.query(Product).filter_by(id=1, name="Laptop").first()
print_product_details(product)
# Out:
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6440>
# id 7
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6800>
# id 18
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC828A920>
# id 24
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6440>
# id 7
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6800>
# id 18
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC828A920>
# id 24
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6A5840>
# id 2
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6440>
# id 7
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6A5300>
# id 8
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203100>
# id 13
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6800>
# id 18
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F57E0>
# id 19
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DC828A920>
# id 24
# name Laptop
# category_id 1
# description A personal computer
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F5BA0>
# id 25
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6A5840>
# id 2
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6A5300>
# id 8
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB203100>
# id 13
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F57E0>
# id 19
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F5BA0>
# id 25
# name Smartphone
# category_id 1
# description A mobile phone
# _sa_instance_state <sqlalchemy.orm.state.InstanceState object at 0x0000024DCB6F6500>
# id 7
# name Laptop
# category_id 1
# description A personal computer

# %%
product = session.query(Product).filter(Product.id == 1).first()
product.name = "Notebook"
session.commit()
product = session.query(Product).filter(Product.id == 1).first()
print_product_details(product)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 2
#       1 product = session.query(Product).filter(Product.id == 1).first()
# ----> 2 product.name = "Notebook"
#       3 session.commit()
#       4 product = session.query(Product).filter(Product.id == 1).first()
#
# AttributeError: 'NoneType' object has no attribute 'name'

# %%
product = session.query(Product).filter(Product.id == 1).first()
session.delete(product)
session.commit()

products = session.query(Product).all()
for product in products:
    for key, value in product.__dict__.items():
        if key == "name":
            print(value)

# %% [markdown]
# Ordering & Pagination

# %%
products = session.query(Product).order_by(Product.name.asc()).limit(2).offset(2)
print_products_details(products)

# %% [markdown]
# Aggregations

# %%
count = session.query(Product.category_id).distinct().count()
print("Distinct category count:", count)

# %%
from sqlalchemy import func



count = session.query(func.count(Product.category_id).distinct()).scalar()
print("Distinct category count:", count)

_sum = session.query(func.sum(Product.category_id)).scalar()
print("Sum of category IDs:", _sum)

avg = session.query(func.avg(Product.category_id)).scalar()
print("Average of category IDs:", avg)

_max = session.query(func.max(Product.category_id)).scalar()
print("Maximum of category IDs:", _max)

_min = session.query(func.min(Product.category_id)).scalar()
print("Minimum of category IDs:", _min)

count, avg, _sum, _max, _min = session.query(
    func.count(Product.category_id), 
    func.avg(Product.category_id),
    func.sum(Product.category_id),
    func.max(Product.category_id),
    func.min(Product.category_id),
).one()

print("Distinct category count:", count)
print("Average of category IDs:", avg)
print("Sum of category IDs:", _sum)
print("Maximum of category IDs:", _max)
print("Minimum of category IDs:", _min)

# %%
products = session.query(Product).all()
for product in products:
    print(product.category.name)

# %%
categories = session.query(Category).join(Category.products).distinct().all()

for category in categories:
    print(category.name, ": ", ", ".join([str(product.name) for product in category.products]))
