# %%
from main import Category, Product, Session, engine

# %%
with Session(engine) as session:
    categories = session.query(Category).all()
    print(categories)
# Out:
# [Category(id=1, name='Electronics', description='Electronic items'), Category(id=2, name='Clothing', description='Clothing items'), Category(id=3, name='Books', description='Books and literature'), Category(id=4, name='Electronics', description='Electronic items'), Category(id=5, name='Clothing', description='Clothing items'), Category(id=6, name='Books', description='Books and literature'), Category(id=7, name='Electronics', description='Electronic items'), Category(id=8, name='Clothing', description='Clothing items'), Category(id=9, name='Books', description='Books and literature'), Category(id=10, name='Electronics', description='Electronic items'), Category(id=11, name='Clothing', description='Clothing items'), Category(id=12, name='Books', description='Books and literature'), Category(id=13, name='Electronics', description='Electronic items'), Category(id=14, name='Clothing', description='Clothing items'), Category(id=15, name='Books', description='Books and literature'), Category(id=16, name='Electronics', description='Electronic items'), Category(id=17, name='Clothing', description='Clothing items'), Category(id=18, name='Books', description='Books and literature'), Category(id=19, name='Electronics', description='Electronic items'), Category(id=20, name='Clothing', description='Clothing items'), Category(id=21, name='Books', description='Books and literature'), Category(id=22, name='Electronics', description='Electronic items'), Category(id=23, name='Clothing', description='Clothing items'), Category(id=24, name='Books', description='Books and literature'), Category(id=25, name='Electronics', description='Electronic items'), Category(id=26, name='Clothing', description='Clothing items'), Category(id=27, name='Books', description='Books and literature'), Category(id=28, name='Electronics', description='Electronic items'), Category(id=29, name='Clothing', description='Clothing items'), Category(id=30, name='Books', description='Books and literature')]

# %%
from sqlalchemy.orm import selectinload
from pydantic import BaseModel


class CategoryOut(BaseModel):
    id: int
    name: str
    description: str
    products: list["ProductOut"]

    class Config:
        from_attributes = True

class ProductOut(BaseModel):
    id: int
    name: str
    description: str
    category_id: int

    class Config:
        from_attributes = True



def get_category(category_id: int):
    with Session(engine) as session:
        # category = session.query(Category).get(category_id)
        category = session.query(
            Category
        ).options(
            selectinload(Category.products)
        ).filter(Category.id == category_id).first()
        
        data = {
            "id": category.id,
            "name": category.name,
            "description": category.description,
            "products": [product for product in category.products],
        }

        print(CategoryOut.model_validate(category))

get_category(1)
# Out:
# [<main.Product object at 0x00000267BDA824D0>, <main.Product object at 0x00000267BDA82050>, <main.Product object at 0x00000267BDA81C90>, <main.Product object at 0x00000267BDA81BD0>, <main.Product object at 0x00000267BDA81810>, <main.Product object at 0x00000267BDA81750>, <main.Product object at 0x00000267BDA81390>, <main.Product object at 0x00000267BDA812D0>, <main.Product object at 0x00000267BDA80F10>, <main.Product object at 0x00000267BDA80E50>, <main.Product object at 0x00000267BDA80A90>, <main.Product object at 0x00000267BDA809D0>, <main.Product object at 0x00000267BDA806D0>, <main.Product object at 0x00000267BDA80340>, <main.Product object at 0x00000267BDA80280>, <main.Product object at 0x00000267BDA82890>, <main.Product object at 0x00000267BDA827D0>]
