# %%
for number in range(1, 10):
    if number % 2 == 0:
        print(f"{number} is even")
print("Finished checking numbers.")

# %%
age = int(input("Enter your age: "))

message = "Eligible to vote." if age >= 18 else "Not eligible to vote."
print(message)

# %%
high_income = False
good_credit = True
student = False

message = "Eligible for loan." if (high_income or good_credit) and not student else "Not eligible for loan."
print(message)

# %%
if 10 == "10":
    print("Equal")
elif "bag" > "apple" and "bag" < "cat":
    print("Bag is between apple and cat")
else:
    print("Not equal")

# %%
for i in range(5):
    print((i + 1) * ".")

# %%
for i in range(0, 10, 3):
    if i % 2 == 0:
        print(f"{i} is even")
else:
    print("No numbers left to process.")

# %%
# Nested loops example
for x in range(3):
    for y in range(3):
        print(f"({x}, {y})")

# %%
command = ""
while command.lower() != "quit":
    command = input("Enter command: ")
    if command.lower() == "start":
        print("Car started...")
    elif command.lower() == "stop":
        print("Car stopped.")
    elif command.lower() != "quit":
        print("I don't understand that...")

# %%
def multiply(*numbers):
    total = 1
    for number in numbers:
        total *= number
    return total


multiply(1, 2, 3, 4, 5)

# %%
def save_user(**user):
    try:
        print(user["id"])
        print(user["name"])
        print(user["age"])
    except Exception as e:
        print(e)


save_user(id=1, name="Jhon", age=22)

# %%
message = "message"

print(message)

def greet(name):
    global message
    message = "local message"
    return message

greet("Mosh")

# %%
def fizz_buzz(number):
    message = None
    if number % 3 == 0:
        message = "fizz"
    if number % 5 == 0:
        message = "buzz"
    if (number % 3 == 0) and (number % 5 == 0):
        message = "fizz buzz"
    return message
    

fizz_buzz(13)

# %%
zeros = [0] * 5
letters = ["a", "b", "c"]
zeros + letters

# %%
list(range(5))

# %%
list("Hello World")

# %%
numbers = list(range(20))
print(numbers[5:10])
print(numbers[::2])
print(numbers[::3])

# %%
first, second, third, *others = numbers
print(first, second, third, others)

# %%
first, *others, last = numbers
print(first, others, last)

# %%
for index, letter in enumerate(letters):
    print(index, letter)

# %%
letters = ["a", "b", "c"]
letters.append("d")
letters.insert(0, "-")
print(letters)
letters.pop(0)
print(letters)
del letters[0:2]
print(letters)
letters.clear()
print(letters)

# %%
letters = ["a", "b", "c", "d"]
print(letters.count("d"))
if "d" in letters:
    print(letters.index("d"))

# %%
import random
numbers = [random.randint(0, 100) for _ in range(10)]
print(numbers)

# %%
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)

print(sorted(numbers, reverse=True))

# %%
items = [
    ("Apple", 5), 
    ("Ball", 15), 
    ("Cat", 10)
]

def sort_item(item):
    return item[1]

items.sort(key=sort_item, reverse=True)
print(items)

# lambda parameter:expression

items = [
    ("Ant", 5), 
    ("Beach", 15), 
    ("C++", 10)
]

items.sort(key=lambda item:item[1], reverse=False)
print(items)

# %%
print(map(lambda item:item[1], items))

for i in map(lambda item:item[1], items):
    print(i)

# %%
x, y = int(input("Enter first number: ")), int(input("Enter second number: "))
((lambda x, y: x * y) (x, y))

# %%
items = [
    ("Apple", 5), 
    ("Ball", 15), 
    ("Cat", 10)
]

print(list(map(lambda x: x[1] >= 5, items)))

print(list(filter(lambda x: x[1] >= 5, items)))

print([item for item in items if item[1] >= 5])

# %%
list_1 = [1, 2, 3, 4, 5]
list_2 = [6, 7, 8, 9, 0]
print(list(zip(list_1, list_2)))
print(list(zip("ABCDE", "abcde")))

# %%
from collections import deque
queue = deque([])
for i in range(3):
    queue.append(i)
print(queue)
print(queue.popleft())

# %%
point = 1, 2
point
point = 1, 
point
point = ()
point = (1, 2) + (3, 4)
point
point = (1, 2) * 3
point
point = tuple([1, 2, 3, 4, 5])
point
print(point[0:2])
if 5 in point:
    print(5)

# %%
x = 1
y = 2

z = x
x = y
y = z
print(f"x: {x}, y: {y}")

x, y = y, x
print(f"x: {x}, y: {y}")

# %%
from array import array
numbers = array("i", [1, 2, 3, 4, 5])
numbers.append(6)
numbers.insert(0, 0)
print(numbers)

# %%
numbers = [1, 1, 2, 3, 3, 4, 5, 6, 6]
print(numbers)
print(set(numbers))

# %%
first = {1, 2, 3}
second = {2, 3, 4, 5, 6}

print(first | second)
print(first & second)
print(first - second)
print(first ^ second)

if 1 in first:
    print(1)

# %%
point = {"x": 1, "y": 2}
point = dict(x = 1, y = 2)
print(point)
if "x" in point:
    print(point["x"])
point = dict(a = 1, b = 2, c = 3)
print(point)
if "b" in point:
    print(point["b"])

point = dict(a= 1, b = [i for i in range(100) if i % 2 == 0], c = [i for i in range(100) if i % 2 == 1])
print(point)
for point_key in point.keys():
    if type(point[point_key]) == int:
            continue
    for point_value in point[point_key]:
        if point_value == 8:
            print(point_key, point_value)

# %%
point = dict(a= 1, b = [i for i in range(100) if i % 2 == 0], c = [i for i in range(100) if i % 2 == 1])
del point["a"]
print(point)

point = dict(a = 1, b = [i for i in range(100) if i % 2 == 0], c = [i for i in range(100) if i % 2 == 1])

try:
    for key, value in point:
        print(key, value)
except Exception as e:
    print(e)

# %%
values = []
for x in range(10):
    values.append(x ** 2)
print(values)
values = list(map(lambda x: x ** 2, range(10)))
print(values)
values = [x ** 2 for x in range(10)]
print(values)
values = list(map(lambda x: "even" if x % 2 == 0 else "odd", range(10)))
print(values)

# %%
values = {x ** 2 for x in range(10)}
print(values)
values = {x:x ** 2 for x in range(10)}
print(values)

# %%
from sys import getsizeof


values = tuple(x ** 2 for x in range(10))
print(values)
values = (x ** 2 for x in range(10))
print(values)
print(getsizeof(values))

# %%
numbers = [1, 2, 3, 4, 5]
print(*numbers)

values = list(range(5))
print(*values)

values = [*range(5)]
print(*values)

values = [*range(5), *"hello"]
print(*values)

first_list = [1, 2, 3]
second_list = [4, 5, 6]

values = [*first_list, *"hello", *second_list, *"world"]
print(*values)

first_dict = {"a": 10, "b": 20}
second_dict = {"c": 30, "d": 40}

values = {**first_dict, **second_dict, "e": 50}
print(values)

# %%
sentence = "This is a common interview question."

char_dict = {}
for char in sentence:
    if char in char_dict:
        char_dict[char] += 1
    else:
        char_dict[char] = 1

max_char = ""
max_count = 0
from pprint import pprint
# pprint(char_dict, width=1)

print(sorted(char_dict.items(), key=lambda key_value:key_value[1], reverse=True))

# %%
try:
    age = int(input("Enter your age: "))
    print("You are", age, "years old.")
except ValueError as e:
    print(e, type(e))

# %%
try:
    file = open("1.py", "r")
    print(file)
except Exception as e:
    print(e, type(e))
finally:
    file.close()

# %%
try:
    number = int(input("Enter a number: "))
    print(number / number)
except Exception as e:
    print(e, type(e))

# %%
try:
    with open("1.py", "r") as file:
        print(file)
        print(file.read())
        print(file.__enter__())
        print(file.__exit__())
except Exception as e:
    print(e, type(e))
finally:
    file.close()

# %%
def calculate_factor(*numbers):
    return numbers[0] + numbers[1] - numbers[2] * numbers[3] / numbers[4]

try:
    print(calculate_factor(5, 10, 15, 20, 0))
except Exception as e:
    print(e, type(e))


def calculate_x_factor(number):
    if number <= 0:
        raise Exception
    return 10 / number

# %%
code = """
def calculate_x_factor(number):
    if number <= 0:
        raise Exception
    return 10 / number

try:
    print(calculate_x_factor(0))
except Exception as e:
    print(e, type(e))
"""

from timeit import timeit
print(timeit(code, number=10000))

# %%
code = """
def calculate_x_factor(number):
    if number <= 0:
        return None
    return 10 / number

try:
    print(calculate_x_factor(0))
except Exception as e:
    print(e, type(e))
"""

print(timeit(code, number=10000))

# %%
# Class: Blueprint for creating objects
# Objects: Instance of a class
# Method: Function inside a class

# Class: Human
# Objects: Jhon, Alice
# Methods: talk(), walk()

class Point:
    default_color = "red"

    def __init__(self, x, y):
        self.x = x
        self.y = y

    @classmethod
    def zero(cls):
        return cls(5, 10)

    def draw(self):
        print(f"Point ({self.x}, {self.y})")

    def __str__(self):
        return f"Point ({self.x}, {self.y})"


point = Point(1, 2)
print(point.x, point.y)
point.draw()
print(type(point))
# Instance vs Class Attributes
print(isinstance(point, Point))
print(Point.default_color)
print(point.default_color)
point.default_color = "blue"
print(point.default_color)
point = point.zero()
print(point.x, point.y)
# Magic Methods
print(point.__dict__)

# %%
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

    @classmethod
    def assign_class_attributes(cls):
        return cls(
            name = "John",
            age = 20,
            gender = "Male"
        )
    
    def talk(self):
        print(f"Hello, my name is {self.name}. I am {self.age} years old and I am a {self.gender}.")

person = Person.assign_class_attributes()
person.talk()

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __eq__(self, value):
        return self.x == value.x and self.y == value.y
    
    def __gt__(self, value):
        return (self.x > value.x) and (self.y > value.y)

    def __add__(self, value):
        return (self.x + value.x, self.y + value.y)
    
point_1 = Point(1, 2)
point_2 = Point(1, 2)
print(point_1 == point_2)
point_1 = Point(3, 4)
point_2 = Point(1, 2)
print(point_1 > point_2)
print(point_1 + point_2)

# %%
class TagCloud:
    def __init__(self):
        self.__tags = {}

    def add(self, tag):
        self.__tags[tag.lower()] = self.__tags.get(tag.lower(), 0) + 1

    def __getitem__(self, tag):
        return self.__tags.get(tag.lower(), 0)
    
    def __setitem__(self, tag, count):
        self.__tags[tag.lower()] = count

    def __len__(self):
        return len(self.__tags)
    
    def __iter__(self):
        return iter(self.__tags)

cloud = TagCloud()
cloud.add("python")
cloud.add("Python")
cloud.add("PYTHON")
print(cloud)
print(cloud["python"])
print(cloud.__dict__)

# %%
class Product:
    def __init__(self, price):
        self.price = price

    @property
    def price(self):
        return self.__price
    
    @price.setter
    def price(self, value):
        if value < 0:
            raise ValueError("Price cannot be negative.")
        self.__price = value




product = Product(50)
print(product.price)

# %%
class Animal:
    def __init__(self):
        print("Animal Constructor")
        self.age = 1

    def eat(self):
        print("eat")

class Mammle(Animal):
    def __init__(self):
        print("Mammle Constructor")
        self.weight = 10
        super().__init__()

    def walk(self):
        print("walk")
    
    def talk(self):
        print("talk")

    def __ge__(self, value):
        return self.age >= value
    
    def __le__(self, value):
        return self.age <= value

class Fish(Animal):
    def swim(self):
        print("swim")
    
    def talk(self):
        print("talk")


mammle = Mammle()
print(f"mammle.age: {mammle.age}")
print(f"mammle.weight: {mammle.weight}")
print(f"mammle.__ge__(22): {mammle.__ge__(22)}")
print(f"mammle.__le__(22): {mammle.__le__(22)}")
print(f"isinstance(mammle, Animal): {isinstance(mammle, Animal)}")
print(f"isinstance(mammle, object): {isinstance(mammle, object)}")
print(dir(object))
print(issubclass(Mammle, Animal))

for method in dir(object):
    print(f"method: {method}")

# %%
class Animal:
    def __init__(self):
        self.age = 1

    def eat(self):
        print("eat")


class Bird(Animal):
    def fly(self):
        print("fly")

class Chicken(Bird):
    pass

# %%
class Employee:
    def greet(self):
        print("Hello")

class Person:
    def greet(self):
        print("Hi")

class Manager_1(Employee, Person):
    pass

class Manager_2(Person, Employee):
    pass

manager_1 = Manager_1()
manager_1.greet()

manager_2 = Manager_2()
manager_2.greet()

# %%
class InvalidOperationError(Exception):
    pass

class Stream:
    def __init__(self):
        self.opened = False

    def open(self):
        if self.opened:
            raise InvalidOperationError("Stream is already opened.")
        self.opened = True
        print("Stream opened.")

    def close(self):
        if not self.opened:
            raise InvalidOperationError("Stream is already closed.")
        self.opened = False
        print("Stream closed.")


class FileStream(Stream):
    def read(self):
        print("Reading data from file stream.")

class NetworkStream(Stream):
    def read(self):
        print("Reading data from network stream.")


file_stream = FileStream()
file_stream.open()
file_stream.read()

network_stream = NetworkStream()
network_stream.open()
network_stream.read()

# %%
# Good example of multiple inheritance
class Flyer:
    def fly(self):
        print("fly")

class Swimmer:
    def swim(self):
        print("swim")


class FlyingFish(Flyer, Swimmer):
    pass

# %%
from abc import ABC, abstractmethod

# Good example of inheritance
class InvalidOperationError(Exception):
    pass


class Stream(ABC):
    def __init__(self):
        self.opened = False

    def open(self):
        if self.opened:
            raise InvalidOperationError("Stream is already opened.")
        self.opened = True
        print("Stream opened.")

    def close(self):
        if not self.opened:
            raise InvalidOperationError("Stream is already closed.")
        self.opened = False
        print("Stream closed.")

    @abstractmethod
    def read(self):
        pass



class FileStream(Stream):
    def read(self):
        print("reading data from file")


class NetwordStream(Stream):
    def read(self):
        print("reading data from network")



file_stream = FileStream()
file_stream.read()
print(file_stream.opened)
file_stream.open()

network_stream = NetwordStream()
network_stream.read()
print(network_stream.opened)
network_stream.open()

# %%
from abc import ABC, abstractmethod

class UIControl(ABC):
    @abstractmethod
    def draw(self):
        print("abstract draw method")
        

class TextBox(UIControl):
    def draw(self):
        print("TextBox draw method")
        super().draw()


class DropDownList(UIControl):
    def draw(self):
        print("DropDownList draw method")
        super().draw()
    
def draw(controls):
    for control in controls:
        control.draw()
    

textbox = TextBox()
textbox.draw()

dropdownlist = DropDownList()
dropdownlist.draw()

draw([textbox, dropdownlist])

# %%
class Text(str):
    def duplicate(self):
        return self + self
    

class TrackableList(list):
    def append(self, object):
        print("Append called")
        return super().append(object)
    

text = Text("Hello")
print(text.duplicate())
trackable_list = TrackableList()
trackable_list.append(1)
print(dir(trackable_list))
for i in range(3):
    trackable_list.append(i)
print(trackable_list)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y


point_1 = Point(1, 2)
point_2 = Point(1, 2)

print(id(point_1), id(point_2))
print(point_1 == point_2)

# %%
from collections import namedtuple

Point = namedtuple("Point", ["x", "y"], defaults=[0, 0])
point_1 = Point(x = 1, y = 2)
print(point_1.x, point_1.y)
point_2 = namedtuple("Point", ["x", "y"], defaults=[0, 0])
point_2 = Point(x = 1, y = 2)
print(point_1 == point_2)
