# %%
import spacy


nlp = spacy.load("en_core_web_sm")

doc = nlp("Artificial Intelligence is a new field of computer science. It is a rapidly growing field.")

for token in doc:
    print(token, " | ", token.pos_, " | ", token.pos, " | ", spacy.explain(token.pos_))
# Out:
# Artificial  |  PROPN  |  96  |  proper noun
# Intelligence  |  PROPN  |  96  |  proper noun
# is  |  AUX  |  87  |  auxiliary
# a  |  DET  |  90  |  determiner
# new  |  ADJ  |  84  |  adjective
# field  |  NOUN  |  92  |  noun
# of  |  ADP  |  85  |  adposition
# computer  |  NOUN  |  92  |  noun
# science  |  NOUN  |  92  |  noun
# .  |  PUNCT  |  97  |  punctuation
# It  |  PRON  |  95  |  pronoun
# is  |  AUX  |  87  |  auxiliary
# a  |  DET  |  90  |  determiner
# rapidly  |  ADV  |  86  |  adverb
# growing  |  VERB  |  100  |  verb
# field  |  NOUN  |  92  |  noun
# .  |  PUNCT  |  97  |  punctuation

# %%
doc = nlp("Natural Language Processing is a new field of computer science. It is a rapidly growing field. It contributes to Artificial Intelligence.")

for token in doc:
    print(token.text, " | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
# Out:
# Natural  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Language  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Processing  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# is  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# a  |  DET  |  determiner  |  DT  |  determiner
# new  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# field  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# computer  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# science  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# It  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# is  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# a  |  DET  |  determiner  |  DT  |  determiner
# rapidly  |  ADV  |  adverb  |  RB  |  adverb
# ...

# %%
import spacy.attrs


text = """Microsoft Corp. today announced the following results for the quarter ended December 31, 2021, as compared to the corresponding period of last fiscal year:
·         Revenue was $51.7 billion and increased 20%
·         Operating income was $22.2 billion and increased 24%
·         Net income was $18.8 billion and increased 21%
·         Diluted earnings per share was $2.48 and increased 22%
“Digital technology is the most malleable resource at the world’s disposal to overcome constraints and reimagine everyday work and life,” said Satya Nadella, chairman and chief executive officer of Microsoft. “As tech as a percentage of global GDP continues to increase, we are innovating and investing across diverse and growing markets, with a common underlying technology stack and an operating model that reinforces a common strategy, culture, and sense of purpose.”
“Solid commercial execution, represented by strong bookings growth driven by long-term Azure commitments, increased Microsoft Cloud revenue to $22.1 billion, up 32% year over year” said Amy Hood, executive vice president and chief financial officer of Microsoft."""

doc = nlp(text)

print(f"Count: {doc.count_by(spacy.attrs.POS)}")

for key, value in doc.count_by(spacy.attrs.POS).items():
    print(f"{doc.vocab[key].text}: {value}")

for token in doc:
    if token.pos_ not in ["SPACE", "PUNCT", "X"]:
        print(token.text, " | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# Count: {96: 15, 92: 45, 100: 23, 90: 9, 85: 16, 93: 16, 97: 27, 98: 1, 84: 20, 103: 10, 87: 6, 99: 5, 89: 12, 86: 3, 94: 3, 95: 2}
# PROPN: 15
# NOUN: 45
# VERB: 23
# DET: 9
# ADP: 16
# NUM: 16
# PUNCT: 27
# SCONJ: 1
# ADJ: 20
# SPACE: 10
# AUX: 6
# SYM: 5
# CCONJ: 12
# ADV: 3
# PART: 3
# PRON: 2
# Microsoft  |  PROPN  |  proper noun
# Corp.  |  PROPN  |  proper noun
# today  |  NOUN  |  noun
# announced  |  VERB  |  verb
# the  |  DET  |  determiner
# following  |  VERB  |  verb
# results  |  NOUN  |  noun
# for  |  ADP  |  adposition
# the  |  DET  |  determiner
# quarter  |  NOUN  |  noun
# ended  |  VERB  |  verb
# December  |  PROPN  |  proper noun
# 31  |  NUM  |  numeral
# 2021  |  NUM  |  numeral
# as  |  SCONJ  |  subordinating conjunction
# compared  |  VERB  |  verb
# to  |  ADP  |  adposition
# the  |  DET  |  determiner
# corresponding  |  ADJ  |  adjective
# period  |  NOUN  |  noun
# of  |  ADP  |  adposition
# last  |  ADJ  |  adjective
# fiscal  |  ADJ  |  adjective
# ...

# %%
text = """
Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.
The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.
Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.
The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.
The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.
Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.
Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.
Credits: cnbc.com
"""

# Extract all NOUN token from the text
doc = nlp(text)
for token in doc:
    if token.pos_ == "NOUN":
        print(token.text, " | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# Inflation  |  NOUN  |  noun
# climb  |  NOUN  |  noun
# consumers  |  NOUN  |  noun
# brink  |  NOUN  |  noun
# expansion  |  NOUN  |  noun
# consumer  |  NOUN  |  noun
# price  |  NOUN  |  noun
# index  |  NOUN  |  noun
# measure  |  NOUN  |  noun
# prices  |  NOUN  |  noun
# goods  |  NOUN  |  noun
# services  |  NOUN  |  noun
# %  |  NOUN  |  noun
# year  |  NOUN  |  noun
# estimate  |  NOUN  |  noun
# %  |  NOUN  |  noun
# gain  |  NOUN  |  noun
# ease  |  NOUN  |  noun
# peak  |  NOUN  |  noun
# level  |  NOUN  |  noun
# summer  |  NOUN  |  noun
# food  |  NOUN  |  noun
# energy  |  NOUN  |  noun
# prices  |  NOUN  |  noun
# core  |  NOUN  |  noun
# %  |  NOUN  |  noun
# expectations  |  NOUN  |  noun
# %  |  NOUN  |  noun
# gain  |  NOUN  |  noun
# hopes  |  NOUN  |  noun
# inflation  |  NOUN  |  noun
# month  |  NOUN  |  noun
# month  |  NOUN  |  noun
# gains  |  NOUN  |  noun
# expectations  |  NOUN  |  noun
# %  |  NOUN  |  noun
# headline  |  NOUN  |  noun
# ...

# %%
# Extract all NUM token from the text
num_token_list = []

for token in doc:
    if token.pos_ == "NUM":
        num_token_list.append(token.text)

print(num_token_list)
# Out:
# ['8.3', '8.1', '1982', '6.2', '6', '0.3', '0.2', '0.6', '0.4', '0.1', '0.3', '2.6', '5.5', '2021', '1984', 'one', 'two', 'two', '2']

# %%
# Print a count of all POS tags in this story
for key, value in doc.count_by(spacy.attrs.POS).items():
    print(doc.vocab[key].text, " | ", spacy.explain(doc.vocab[key].text), " : ", value)
# Out:
# SPACE  |  space  :  9
# NOUN  |  noun  :  96
# VERB  |  verb  :  27
# ADV  |  adverb  :  15
# ADP  |  adposition  :  39
# PROPN  |  proper noun  :  16
# PUNCT  |  punctuation  :  32
# DET  |  determiner  :  34
# PRON  |  pronoun  :  4
# AUX  |  auxiliary  :  13
# CCONJ  |  coordinating conjunction  :  10
# ADJ  |  adjective  :  23
# NUM  |  numeral  :  19
# PART  |  particle  :  4
# SCONJ  |  subordinating conjunction  :  8
# X  |  other  :  1
